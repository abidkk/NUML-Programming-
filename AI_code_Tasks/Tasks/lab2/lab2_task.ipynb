# %% [markdown]
# ## LAB 2:
# - Name: Ali Abid
# - Roll: BSCS-KC-006

# %% [markdown]
# ### 3.6.1 LAB TASK 1:
# - Write a program to find the largest of ten numbers provided by user, using functions.

# %%
nums = []
def find_largest(numbers):
    try:
        input_str = input("Enter ten numbers separated by spaces: ")
        numbers = [int(num) for num in input_str.split()]  # Converting to integer
        global nums 
        nums = numbers

        if not numbers:  # in case of emtpy list
            return 0

        largest_number = numbers[0]  
        for number in numbers:
            if number > largest_number:
                largest_number = number
        print(numbers)
        return f"The Largest Number is {largest_number}"
    except Exception as e:
        return e
    
find_largest(nums) ## Function Calling
# Out:
# [10, 20, 30, 40, 50, 90, 80, 70, 60, 80]
# 'The Largest Number is 90'

# %% [markdown]
# ### 3.6.2 LAB TASK 2:
# - Create a class name basic_calc with following attributes and methods;
# - Two integers (values are passed with instance creation)
# - Different methods such as addition, subtraction, division, multiplication

# %%
class BasicCalc:
    # constructor
    def __init__(self, num1, num2):
        self.num1 = num1
        self.num2 = num2

    # Methods 1:  SUM
    def sum(self):
        print(f"SUM of Two Numers: {self.num1+self.num2}")

    # Methods 2:  Subtract
    def subtract(self):
        print(f"Subtraction of Two Numers: {self.num1 - self.num2}")

    # Method 3:  Multiplication
    def multi(self):
        print(f"Multiplicaiton of Two Numers: {self.num1 * self.num2}")

       # Method 4:  Division
    def division(self):
        print(f"Division of Two Numers: {self.num1 / self.num2}")
    
# object or instances
obj1 = BasicCalc(20,10)
obj1.sum()
obj1.subtract()
obj1.multi()
obj1.division()
# Out:
# SUM of Two Numers: 30
# Subtraction of Two Numers: 10
# Multiplicaiton of Two Numers: 200
# Division of Two Numers: 2.0
